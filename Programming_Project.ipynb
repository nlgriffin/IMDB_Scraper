# %%
#Import relevant libraries
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import requests
from time import sleep
from random import randint

# %%
#Create a dictionary to store scrape data in (features as keys)
dict_movies = {'genre_0': [],
'genre_1': [],
'genre_2': [],
'genre_3': [],
'country': [],
'language': [],
'filming_locs':  [],
'production_co':  [],
'runtime':  [],
'budget':  [],
'gross_usa':  [],
'release': [],
'director':  [],
'rating': [],
'star_0': [],
'star_1': [],
'star_2': [],
'star_3': [],
'writer_0': [],
'writer_1': [],
'writer_2': [],
'review_count': [],
'title': [],
'open_week': [],
'cumulative': []}

# %%
#Create a list of URLS to scrape
urls = ['https://www.imdb.com/title/tt2975590/?ref_=adv_li_i','https://www.imdb.com/title/tt2404233/?ref_=adv_li_i', 'https://www.imdb.com/title/tt2674426/?ref_=adv_li_i', 'https://www.imdb.com/title/tt2119532/?ref_=adv_li_i', 'https://www.imdb.com/title/tt1386697/?ref_=adv_li_i', 'https://www.imdb.com/title/tt4649466/?ref_=adv_li_i', 'https://www.imdb.com/title/tt1485796/?ref_=adv_li_i', 'https://www.imdb.com/title/tt0974015/?ref_=adv_li_i', 'https://www.imdb.com/title/tt1396484/?ref_=adv_li_i', 'https://www.imdb.com/title/tt5814060/?ref_=adv_li_i', 'https://www.imdb.com/title/tt3799232/?ref_=adv_li_i', 'https://www.imdb.com/title/tt6533240/?ref_=adv_li_i', 'https://www.imdb.com/title/tt6911608/?ref_=adv_li_i', 'https://www.imdb.com/title/tt3606756/?ref_=adv_li_i', 'https://www.imdb.com/title/tt5164214/?ref_=adv_li_i', 'https://www.imdb.com/title/tt1365519/?ref_=adv_li_i','https://www.imdb.com/title/tt2704998/?ref_=adv_li_i', 'https://www.imdb.com/title/tt1677720/?ref_=adv_li_i', 'https://www.imdb.com/title/tt3104988/?ref_=adv_li_i', 'https://www.imdb.com/title/tt6966692/?ref_=adv_li_i', 'https://www.imdb.com/title/tt5463162/?ref_=adv_li_i', 'https://www.imdb.com/title/tt4154756/?ref_=adv_li_i', 'https://www.imdb.com/title/tt2709692/?ref_=adv_li_i', 'https://www.imdb.com/title/tt0816692/?ref_=fn_al_tt_1', 'https://www.imdb.com/title/tt3315342/','https://www.imdb.com/title/tt1754316/','https://www.imdb.com/title/tt7394816/', 'https://www.imdb.com/title/tt1950235/', 'https://www.imdb.com/title/tt0137523/']

# %%
#loop through urls and scrape relevant features
for url in urls:
    resp = requests.get(url)
    
    #Pause the loop
    sleep(randint(8,15))

    #Error if  status codes is not 200
    if resp.status_code != 200:
        warn('Request: {}; Status code: {}'.format(request, response.status_code))
    
    soup = BeautifulSoup(resp.text, 'html.parser')
    
    #get genres
    genres = soup.find_all('div', class_ = 'see-more inline canwrap')[1].find_all('a')
    dict_movies['genre_0'].append(genres[0].text)
    try:
        dict_movies['genre_1'].append(genres[1].text)
    except:
        dict_movies['genre_1'].append("")
    try:
        dict_movies['genre_2'].append(genres[2].text)
    except:
        dict_movies['genre_2'].append("")
    try:
        dict_movies['genre_3'].append(genres[3].text)
    except:
        dict_movies['genre_3'].append("")
    
    #Get country, language, filming location, production co, budget info variables
    other_specs = soup.find_all('div', class_ = 'txt-block')
    for i in range(len(other_specs)):
        if other_specs[i].find('h4', class_ = 'inline') is None:
            continue
        elif 'Country' in other_specs[i].find('h4', class_ = 'inline').text:
            dict_movies['country'].append(other_specs[i].a.text)
        elif 'Language' in other_specs[i].find('h4', class_ = 'inline').text:
            dict_movies['language'].append(other_specs[i].a.text)
        elif 'Filming Locations' in other_specs[i].find('h4', class_ = 'inline').text:
            dict_movies['filming_locs'].append(other_specs[i].a.text)
        elif 'Production Co' in other_specs[i].find('h4', class_ = 'inline').text:
            dict_movies['production_co'].append(other_specs[i].a.text)
        elif 'Runtime' in other_specs[i].find('h4', class_ = 'inline').text:
            dict_movies['runtime'].append(other_specs[i].time.text)
        elif 'Budget' in other_specs[i].find('h4', class_ = 'inline').text:
            try:
                dict_movies['budget'].append(other_specs[i].text)
            except: 
                dict_movies['budget'].append("")
        elif 'Gross USA' in other_specs[i].find('h4', class_ = 'inline').text:
            try:
                dict_movies['gross_usa'].append(other_specs[i].text)
            except:
                dict_movies['gross_usa'].append("")
        elif 'Opening Weekend USA' in other_specs[i].find('h4', class_ = 'inline').text:
            try:
                dict_movies['open_week'].append(other_specs[i].text)
            except:
                dict_movies['open_week'].append("")
        elif 'Cumulative Worldwide Gross' in other_specs[i].find('h4', class_ = 'inline').text:
            try:
                dict_movies['cumulative'].append(other_specs[i].text)
            except:
                dict_movies['cumulative'].append("")

    #get release date
    dict_movies['release'].append(soup.find_all('div', class_ = 'subtext')[0].find_all('a', title = "See more release dates")[0].text)
    
    #Get director, writer and stars    
    movie_containers = soup.find_all('div', class_ = 'credit_summary_item')
    dict_movies['director'].append(movie_containers[0].a.text)
    writers = movie_containers[1].find_all('a')
    dict_movies['writer_0'].append(writers[0].text)
    try:
        dict_movies['writer_1'].append(writers[1].text)
    except:
        dict_movies['writer_1'].append("")     
    try:
        dict_movies['writer_2'].append(writers[2].text)
    except:
        dict_movies['writer_2'].append("")
    stars = movie_containers[2].find_all('a')
    dict_movies['star_0'].append(stars[0].text)
    dict_movies['star_1'].append(stars[1].text)
    dict_movies['star_2'].append(stars[2].text)
    try:
        dict_movies['star_3'].append(stars[3].text)
    except:
        dict_movies['star_3'].append("")
        
    #Get raitng, review count and the title of the movie
    dict_movies['rating'].append(soup.find_all('span',{'itemprop':'ratingValue'})[0].text)
    dict_movies['review_count'].append(soup.find_all('span',{'itemprop':'ratingCount'})[0].text)
    dict_movies['title'].append(soup.find_all('title')[0].text)

# %%
#Convert scraping result dictionary into pandas dataframe
import pandas as pd
movies = pd.DataFrame.from_dict(dict_movies, orient='index').transpose()
movies
# Out:
#                                                               0   \
# genre_0                                                   Action
# genre_1                                                Adventure
# genre_2                                                   Sci-Fi
# genre_3
# country                                                      USA
# language                                                 English
# filming_locs                              Detroit, Michigan, USA
# production_co                                       Warner Bros.
# runtime                                                  151 min
# budget          \nBudget:$250,000,000\n            (estimated)\n
# gross_usa                      \nGross USA: $330,360,194
# release                                    25 March 2016 (USA)\n
# director                                             Zack Snyder
# rating                                                       6.5
# star_0                                               Ben Affleck
# star_1                                              Henry Cavill
# star_2                                                 Amy Adams
# star_3                                      See full cast & crew
# writer_0                                            Chris Terrio
# writer_1                                          David S. Goyer
# writer_2                                          5 more credits
# review_count                                             590,588
# title           Batman v Superman: Dawn of Justice (2016) - IMDb
# open_week      \nOpening Weekend USA: $166,007,347,\n27 March...
# cumulative     \nCumulative Worldwide Gross: $873,634,919    ...
#
#                                                               1   \
# genre_0                                                   Action
# genre_1                                                Adventure
# genre_2                                                  Fantasy
# genre_3
# country                                                      USA
# language                                                 English
# filming_locs   Fox Studios, Moore Park, Sydney, New South Wal...
# production_co                                          Pyramania
# runtime                                                  127 min
# budget          \nBudget:$140,000,000\n            (estimated)\n
# gross_usa                       \nGross USA: $31,153,464
# release                                 26 February 2016 (USA)\n
# director                                             Alex Proyas
# rating                                                       5.4
# star_0                                          Brenton Thwaites
# star_1                                     Nikolaj Coster-Waldau
# star_2                                             Gerard Butler
# star_3                                      See full cast & crew
# writer_0                                             Matt Sazama
# writer_1                                          Burk Sharpless
# writer_2
# review_count                                              98,042
# title                                Gods of Egypt (2016) - IMDb
# open_week      \nOpening Weekend USA: $14,123,903,\n28 Februa...
# cumulative     \nCumulative Worldwide Gross: $150,680,864    ...
#
#                                                               2   \
# genre_0                                                    Drama
# genre_1                                                  Romance
# genre_2
# genre_3
# country                                                       UK
# language                                                 English
# filming_locs           Pembroke Castle, Pembrokeshire, Wales, UK
# production_co                          Metro-Goldwyn-Mayer (MGM)
# runtime                                                  106 min
# budget           \nBudget:$20,000,000\n            (estimated)\n
# gross_usa                       \nGross USA: $56,245,075
# release                                      3 June 2016 (USA)\n
# director                                           Thea Sharrock
# rating                                                       7.4
# star_0                                             Emilia Clarke
# star_1                                               Sam Claflin
# star_2                                              Janet McTeer
# star_3                                      See full cast & crew
# writer_0                                              Jojo Moyes
# writer_1                                              Jojo Moyes
# writer_2
# review_count                                             184,265
# title                                Me Before You (2016) - IMDb
# open_week      \nOpening Weekend USA: $18,723,269,\n5 June 2016
# cumulative     \nCumulative Worldwide Gross: $208,314,186    ...
#
#                                                               3   \
# genre_0                                                Biography
# genre_1                                                    Drama
# genre_2                                                  History
# genre_3                                                      War
# country                                                Australia
# language                                                 English
# filming_locs                  Sydney, New South Wales, Australia
# production_co                               Cross Creek Pictures
# runtime                                                  139 min
# budget           \nBudget:$40,000,000\n            (estimated)\n
# gross_usa                       \nGross USA: $67,209,615
# release                                  4 November 2016 (USA)\n
# director                                              Mel Gibson
# rating                                                       8.1
# star_0                                           Andrew Garfield
# star_1                                           Sam Worthington
# star_2                                               Luke Bracey
# star_3                                      See full cast & crew
# writer_0                                        Robert Schenkkan
# writer_1                                           Andrew Knight
# writer_2
# review_count                                             384,830
# title                                Hacksaw Ridge (2016) - IMDb
# open_week      \nOpening Weekend USA: $15,190,758,\n6 Novembe...
# cumulative     \nCumulative Worldwide Gross: $175,302,354    ...
#
#                                                               4   \
# genre_0                                                   Action
# genre_1                                                Adventure
# genre_2                                                  Fantasy
# genre_3                                                   Sci-Fi
# country                                                      USA
# language                                                 English
# filming_locs                            Toronto, Ontario, Canada
# production_co                                Atlas Entertainment
# runtime                                                  123 min
# budget          \nBudget:$175,000,000\n            (estimated)\n
# gross_usa                      \nGross USA: $325,100,054
# release                                    5 August 2016 (USA)\n
# director                                              David Ayer
# rating                                                       6.0
# star_0                                                Will Smith
# star_1                                                Jared Leto
# star_2                                             Margot Robbie
# star_3                                      See full cast & crew
# writer_0                                              David Ayer
# writer_1
# writer_2
# review_count                                             554,712
# title                                Suicide Squad (2016) - IMDb
# open_week      \nOpening Weekend USA: $133,682,248,\n7 August...
# cumulative     \nCumulative Worldwide Gross: $746,846,894    ...
#
#                                                               5   \
# genre_0                                                   Action
# genre_1                                                Adventure
# genre_2                                                   Comedy
# genre_3
# country                                                       UK
# language                                                 English
# filming_locs                      Camberley, Surrey, England, UK
# production_co                              Twentieth Century Fox
# runtime                                                  141 min
# budget          \nBudget:$104,000,000\n            (estimated)\n
# gross_usa                      \nGross USA: $100,234,838
# release                                22 September 2017 (USA)\n
# director                                          Matthew Vaughn
# rating                                                       6.8
# star_0                                             Taron Egerton
# star_1                                               Colin Firth
# star_2                                               Mark Strong
# star_3                                      See full cast & crew
# writer_0                                            Jane Goldman
# writer_1                                          Matthew Vaughn
# writer_2                                          2 more credits
# review_count                                             243,373
# title                  Kingsman: The Golden Circle (2017) - IMDb
# open_week      \nOpening Weekend USA: $39,023,010,\n24 Septem...
# cumulative     \nCumulative Worldwide Gross: $410,902,662    ...
#
#                                                               6   \
# genre_0                                                Biography
# genre_1                                                    Drama
# genre_2                                                  Musical
# genre_3
# country                                                      USA
# language                                                 English
# filming_locs           1 E 78th St, New York City, New York, USA
# production_co                              Chernin Entertainment
# runtime                                                  105 min
# budget           \nBudget:$84,000,000\n            (estimated)\n
# gross_usa                      \nGross USA: $174,340,174
# release                                 20 December 2017 (USA)\n
# director                                          Michael Gracey
# rating                                                       7.6
# star_0                                              Hugh Jackman
# star_1                                         Michelle Williams
# star_2                                                 Zac Efron
# star_3                                      See full cast & crew
# writer_0                                             Jenny Bicks
# writer_1                                             Bill Condon
# writer_2                                           1 more credit
# review_count                                             208,836
# title                         The Greatest Showman (2017) - IMDb
# open_week      \nOpening Weekend USA: $8,805,843,\n24 Decembe...
# cumulative     \nCumulative Worldwide Gross: $434,993,183    ...
#
#                                                               7   \
# genre_0                                                   Action
# genre_1                                                Adventure
# genre_2                                                  Fantasy
# genre_3                                                   Sci-Fi
# country                                                      USA
# language                                                 English
# filming_locs   Leavesden Studios, Leavesden, Hertfordshire, E...
# production_co                                       Warner Bros.
# runtime                                                  120 min
# budget          \nBudget:$300,000,000\n            (estimated)\n
# gross_usa                      \nGross USA: $229,024,295
# release                                 17 November 2017 (USA)\n
# director                                             Zack Snyder
# rating                                                       6.4
# star_0                                               Ben Affleck
# star_1                                                 Gal Gadot
# star_2                                               Jason Momoa
# star_3                                      See full cast & crew
# writer_0                                            Jerry Siegel
# writer_1                                             Joe Shuster
# writer_2                                          9 more credits
# review_count                                             346,431
# title                               Justice League (2017) - IMDb
# open_week      \nOpening Weekend USA: $93,842,239,\n19 Novemb...
# cumulative     \nCumulative Worldwide Gross: $657,924,295    ...
#
#                                                               8   \
# genre_0                                                   Horror
# genre_1
# genre_2
# genre_3
# country                                                      USA
# language                                                 English
# filming_locs                            Toronto, Ontario, Canada
# production_co                                    New Line Cinema
# runtime                                                  135 min
# budget           \nBudget:$35,000,000\n            (estimated)\n
# gross_usa                      \nGross USA: $327,481,748
# release                                 8 September 2017 (USA)\n
# director                                         Andy Muschietti
# rating                                                       7.3
# star_0                                            Bill Skarsgård
# star_1                                            Jaeden Martell
# star_2                                             Finn Wolfhard
# star_3                                      See full cast & crew
# writer_0                                            Chase Palmer
# writer_1                                      Cary Joji Fukunaga
# writer_2                                          2 more credits
# review_count                                             409,647
# title                                           It (2017) - IMDb
# open_week      \nOpening Weekend USA: $123,403,419,\n10 Septe...
# cumulative     \nCumulative Worldwide Gross: $700,449,318    ...
#
#                                                               9   ...  \
# genre_0                                                   Horror  ...
# genre_1                                                  Mystery  ...
# genre_2                                                 Thriller  ...
# genre_3                                                           ...
# country                                                      USA  ...
# language                                                 English  ...
# filming_locs             Castel Film Studios, Bucharest, Romania  ...
# production_co                                     Atomic Monster  ...
# runtime                                                   96 min  ...
# budget           \nBudget:$22,000,000\n            (estimated)\n  ...
# gross_usa                      \nGross USA: $117,450,119          ...
# release                                 7 September 2018 (USA)\n  ...
# director                                             Corin Hardy  ...
# rating                                                       5.3  ...
# star_0                                             Demián Bichir  ...
# star_1                                            Taissa Farmiga  ...
# star_2                                             Jonas Bloquet  ...
# star_3                                      See full cast & crew  ...
# writer_0                                          Gary Dauberman  ...
# writer_1                                               James Wan  ...
# writer_2                                           1 more credit  ...
# review_count                                             101,856  ...
# title                                      The Nun (2018) - IMDb  ...
# open_week      \nOpening Weekend USA: $53,807,379,\n9 Septemb...  ...
# cumulative     \nCumulative Worldwide Gross: $365,550,119    ...  ...
#
#                                                               19  \
# genre_0                                                Biography
# genre_1                                                   Comedy
# genre_2                                                    Drama
# genre_3                                                    Music
# country                                                      USA
# language                                                 English
# filming_locs         Carnegie Hall, New York City, New York, USA
# production_co                                        Participant
# runtime                                                  130 min
# budget          \nBudget:$321,000,000\n            (estimated)\n
# gross_usa                      \nGross USA: $678,815,482
# release                                 16 November 2018 (USA)\n
# director                                          Peter Farrelly
# rating                                                       8.2
# star_0                                           Viggo Mortensen
# star_1                                            Mahershala Ali
# star_2                                          Linda Cardellini
# star_3                                      See full cast & crew
# writer_0                                         Nick Vallelonga
# writer_1                                      Brian Hayes Currie
# writer_2                                           1 more credit
# review_count                                             262,299
# title                                   Green Book (2018) - IMDb
# open_week      \nOpening Weekend USA: $257,698,183,\n29 April...
# cumulative     \nCumulative Worldwide Gross: $785,046,920    ...
#
#                                                               20  \
# genre_0                                                   Action
# genre_1                                                Adventure
# genre_2                                                   Comedy
# genre_3                                                   Sci-Fi
# country                                                      USA
# language                                                 English
# filming_locs                 Vancouver, British Columbia, Canada
# production_co                              Twentieth Century Fox
# runtime                                                  119 min
# budget           \nBudget:$75,000,000\n            (estimated)\n
# gross_usa                      \nGross USA: $270,620,950
# release                                      18 May 2018 (USA)\n
# director                                            David Leitch
# rating                                                       7.7
# star_0                                             Ryan Reynolds
# star_1                                               Josh Brolin
# star_2                                           Morena Baccarin
# star_3                                      See full cast & crew
# writer_0                                             Rhett Reese
# writer_1                                            Paul Wernick
# writer_2                                           1 more credit
# review_count                                             425,515
# title                                   Deadpool 2 (2018) - IMDb
# open_week      \nOpening Weekend USA: $67,572,855,\n11 Novemb...
# cumulative     \nCumulative Worldwide Gross: $2,048,359,754  ...
#
#                                                               21  \
# genre_0                                                   Action
# genre_1                                                Adventure
# genre_2                                                   Sci-Fi
# genre_3
# country                                                      USA
# language                                                 English
# filming_locs   Pinewood Atlanta Studios - 461 Sandy Creek Roa...
# production_co                                     Marvel Studios
# runtime                                                  149 min
# budget          \nBudget:$165,000,000\n            (estimated)\n
# gross_usa                      \nGross USA: $188,020,017
# release                                    27 April 2018 (USA)\n
# director                                           Anthony Russo
# rating                                                       8.5
# star_0                                         Robert Downey Jr.
# star_1                                           Chris Hemsworth
# star_2                                              Mark Ruffalo
# star_3                                      See full cast & crew
# writer_0                                      Christopher Markus
# writer_1                                         Stephen McFeely
# writer_2                                         14 more credits
# review_count                                             727,078
# title                       Avengers: Infinity War (2018) - IMDb
# open_week      \nOpening Weekend USA: $47,510,360,\n9 Novembe...
# cumulative     \nCumulative Worldwide Gross: $511,595,957    ...
#
#                                                               22  \
# genre_0                                                Animation
# genre_1                                                   Family
# genre_2                                                  Fantasy
# genre_3
# country                                                   France
# language                                                 English
# filming_locs   Illumination Entertainment - 1805 Colorado Ave...
# production_co                                 Universal Pictures
# runtime                                                   85 min
# budget           \nBudget:$97,000,000\n            (estimated)\n
# gross_usa                      \nGross USA: $226,277,068
# release                                  9 November 2018 (USA)\n
# director                                           Yarrow Cheney
# rating                                                       6.3
# star_0                                      Benedict Cumberbatch
# star_1                                             Cameron Seely
# star_2                                             Rashida Jones
# star_3                                      See full cast & crew
# writer_0                                         Michael LeSieur
# writer_1                                          Tommy Swerdlow
# writer_2                                           1 more credit
# review_count                                              34,433
# title                        Dr. Seuss' The Grinch (2018) - IMDb
# open_week      \nOpening Weekend USA: $88,411,916,\n5 March 2...
# cumulative     \nCumulative Worldwide Gross: $677,471,339    ...
#
#                                                               23  \
# genre_0                                                Adventure
# genre_1                                                    Drama
# genre_2                                                   Sci-Fi
# genre_3
# country                                                      USA
# language                                                 English
# filming_locs                            Okotoks, Alberta, Canada
# production_co                                 Paramount Pictures
# runtime                                                  169 min
# budget           \nBudget:$63,000,000\n            (estimated)\n
# gross_usa                       \nGross USA: $37,030,102
# release                                  7 November 2014 (USA)\n
# director                                       Christopher Nolan
# rating                                                       8.6
# star_0                                       Matthew McConaughey
# star_1                                             Anne Hathaway
# star_2                                          Jessica Chastain
# star_3                                      See full cast & crew
# writer_0                                          Jonathan Nolan
# writer_1                                       Christopher Nolan
# writer_2
# review_count                                           1,350,225
# title                                 Interstellar (2014) - IMDb
# open_week      \nOpening Weekend USA: $11,035,485,\n17 Octobe...
# cumulative     \nCumulative Worldwide Gross: $619,021,436    ...
#
#                                                               24  \
# genre_0                                                   Action
# genre_1                                                    Drama
# genre_2                                                   Sci-Fi
# genre_3                                                 Thriller
# country                                                      USA
# language                                                 English
# filming_locs   Just outside Northern Meadows community, Rio R...
# production_co                              Twentieth Century Fox
# runtime                                                  137 min
# budget                                                      None
# gross_usa                                                   None
# release                                     3 March 2017 (USA)\n
# director                                           James Mangold
# rating                                                       8.1
# star_0                                              Hugh Jackman
# star_1                                           Patrick Stewart
# star_2                                                Dafne Keen
# star_3                                      See full cast & crew
# writer_0                                           James Mangold
# writer_1                                             Scott Frank
# writer_2                                          2 more credits
# review_count                                             587,186
# title                                        Logan (2017) - IMDb
# open_week                                                   None
# cumulative     \nCumulative Worldwide Gross: $101,187,503    ...
#
#                                            25                           26  \
# genre_0                                Action                       Action
# genre_1                                 Drama
# genre_2                              Thriller
# genre_3
# country                                   USA                          USA
# language                              English                      English
# filming_locs      Lake Tahoe, California, USA                  Puerto Rico
# production_co                        Ox Films   Daniel Grodnik Productions
# runtime                                97 min                       92 min
# budget                                   None                         None
# gross_usa                                None                         None
# release               22 January 2019 (USA)\n      8 November 2019 (USA)\n
# director                         Richard Ryan                  Nick Powell
# rating                                    3.6                          4.9
# star_0                       Micah Fitzgerald                 Nicolas Cage
# star_1                            Anzu Lawson                Famke Janssen
# star_2                         Mark Sivertsen                 Kevin Durand
# star_3                   See full cast & crew         See full cast & crew
# writer_0                         Richard Ryan                Richard Leder
# writer_1                     Michael Marcelin
# writer_2
# review_count                              187                        1,385
# title          Art of Deception (2019) - IMDb         Primal (2019) - IMDb
# open_week                                None                         None
# cumulative                               None                         None
#
#                                       27  \
# genre_0                           Comedy
# genre_1                          Romance
# genre_2
# genre_3
# country                              USA
# language                         English
# filming_locs    Toronto, Ontario, Canada
# production_co    Dylan Clark Productions
# runtime                          139 min
# budget                              None
# gross_usa                           None
# release          8 November 2019 (USA)\n
# director                    Luke Snellin
# rating                               5.8
# star_0                    Isabela Merced
# star_1                     Shameik Moore
# star_2                        Odeya Rush
# star_3              See full cast & crew
# writer_0                     Laura Solon
# writer_1                Victoria Strouse
# writer_2                  4 more credits
# review_count                       7,341
# title          Let It Snow (2019) - IMDb
# open_week                           None
# cumulative                          None
#
#                                                               28
# genre_0                                                    Drama
# genre_1
# genre_2
# genre_3
# country                                                      USA
# language                                                 English
# filming_locs   421 W. Eighth Street, Los Angeles, California,...
# production_co                                  Fox 2000 Pictures
# runtime                                                     None
# budget                                                      None
# gross_usa                                                   None
# release                                  15 October 1999 (USA)\n
# director                                           David Fincher
# rating                                                       8.8
# star_0                                                 Brad Pitt
# star_1                                             Edward Norton
# star_2                                                 Meat Loaf
# star_3                                      See full cast & crew
# writer_0                                         Chuck Palahniuk
# writer_1                                                Jim Uhls
# writer_2
# review_count                                           1,727,412
# title                                   Fight Club (1999) - IMDb
# open_week                                                   None
# cumulative                                                  None
#
# [25 rows x 29 columns]

# %%
#Export dataframe to csv
movies.to_csv('movies_scraping.csv',sep=',', index = None)
